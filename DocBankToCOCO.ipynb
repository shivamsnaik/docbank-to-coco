# %%
import pandas
from pycocotools.coco import COCO
import numpy as np
import pandas as pd 
import os
import matplotlib.pyplot as plt
from glob import glob
from pathlib import Path
import json 
# %matplotlib inline

# %%
import os
import numpy as np
import matplotlib.pyplot as plt
from pathlib import Path
import pandas as pd
import json
from pprint import PrettyPrinter as pprint
from IPython.display import JSON
import re
from tqdm import tqdm
import traceback

class COCOData:
    """
        COCOData class allows DocBank dataset to be converted to COCO Format.

        Functions Available:

        1. read_src_folder(src_path, dest_path): Reads all the DocBank JSON label files from the provided parent path and stores the destination path for later use to save the converted labels.
        2. create_dict_layout(): Creates a basic layout for COCO format with basic static information.
        3. set_image_properties(file_name, image_id): Sets Image Properties. Used in convert_to_coco() function.
        4. set_caption_properties(object_dict, doc_object): Set Caption Properties. Used in set_object_properties() function.
        5. set_object_properties(doc_object, doc_object_id, image_id): Set the Object properties. Used in convert_to_coco() function.
        6. convert_to_coco(): Convert the source dataset to COCO format and store the converted data in coco_dictionary.
        7. save_coco_dataset(): Saves the converted dataset into the destination folder (Destination Folder was provided in read_src_folder function).
    """
    

    
    def __init__(self):
        self.src_file_path = []
        self.coco_file_path = []
        self.src_dictionary = []
        self.coco_dictionary = []
    
    def read_src_folder(self, src_path, dest_path):
       """
       Stores the full path of the JSON files into self.src_file_path
       Stores the content of the source JSON files into self.coco_dictionary
       Stores the full path to the new files (in COCO format)
       """
       i=0
       # Fetch each text file from the folders
       for path in tqdm(Path(src_path).rglob('*.txt'), desc="Loading Source Files"):
            # if i == 100000:
            #     return
            # i+=1
            # Open the file and read the content in JSON datatype
            file = pd.read_table(path, header=None, names=["token", "x0","y0", "x1", "y1", "R", "G","B", "name", "label"])
            
            # Prepare string for coco format json file
            coco_file_path = str(path).replace(".txt", ".json")
            coco_file_path = coco_file_path.replace("DocBank", "DocBank-coco")
            coco_file_path = coco_file_path.replace(src_path, dest_path)

            self.src_file_path.append(str(path))
            self.src_dictionary.append(file)
            self.coco_file_path.append(str(coco_file_path))

    def create_dict_layout(self):
        temp_dict = {}
        temp_dict["info"] = {
            "year": "",
            "version": "1",
            "description": "",
            "contributor": "",
            "url": "",
            "date_created": "",
        }
        temp_dict["licenses"] = []
        
        ['abstract',
         'author',
         'caption',
         'equation',
         'figure',
         'footer',
         'list',
         'paragraph',
         'reference',
         'section',
         'table',
         'title']
        temp_dict["categories"] = [{"id": 0,"name": "Abstract","supercategory": ""},{"id": 1,"name": "Author","supercategory": ""},
            {"id": 2,"name": "Caption","supercategory": ""},{"id": 3,"name": "Equation","supercategory": ""},
            {"id": 4,"name": "Figure","supercategory": ""},{"id": 5,"name": "Footer","supercategory": ""},
            {"id": 6,"name": "List","supercategory": ""},{"id": 7,"name": "Paragraph","supercategory": ""},
            {"id": 8,"name": "Reference","supercategory": ""},{"id": 9,"name": "Section","supercategory": ""},
            {"id": 10,"name": "Table","supercategory": ""},{"id": 11,"name": "Title","supercategory": ""},
            {"id": 12,"name": "Date","supercategory": ""}]
        temp_dict["images"] = []
        temp_dict["annotations"] = []
        
        return temp_dict
    
    # Image denotes the image of a page where a set of objects exist
    def set_image_properties(self, file_name, image_id):
        # Get parent folder and the json file name separately.
        image_path, image_name = os.path.split(file_name)
        image_dict = {
            "id": image_id,
            "license": "",
            "file_name": image_name,
            "height": "",
            "width": "",
            "date_captured": "",
        } 
        return image_dict
     
    # Object denotes either a Table or Figure
    def set_object_properties(self, doc_object, doc_object_id, image_id):
        object_dict = {}
        object_dict["id"] = doc_object_id
        object_dict["image_id"] = image_id
        object_dict["iscrowd"] = 0
        object_dict["segmentation"] = []
        
        category_list = {
            'abstract': 0, 'author': 1, 'caption': 2, 'equation': 3, 'figure': 4, 'footer': 5, 
             'list': 6, 'paragraph': 7, 'reference': 8, 'section': 9, 'table': 10, 'title': 11, "date": 12}
            
        object_dict["category_id"] = category_list[doc_object[9]]
        object_width = doc_object[3] - doc_object[1],
        object_height = doc_object[4] - doc_object[2],
        
        object_dict["bbox"] = [
            int(doc_object[1]),
            int(doc_object[2]),
            int(object_width[0]),
            int(object_height[0])
        ]
        object_dict["area"] = int(object_width[0] * object_height[0]) 
        # self.set_caption_properties(object_dict, doc_object)
        
        return object_dict
    
    def set_caption_properties(self, object_dict, doc_object):
        object_dict["caption"] = doc_object["caption_text"]
                               
    def convert_to_coco(self):
        try:
            # Init Image ID
            image_id = 0
            # Init Object ID
            doc_object_id = 0

            # Fetch each JSON file present in the folders
            for i in tqdm(range(len(self.src_file_path)), desc="Convering Source JSON to COCO JSON"):
                json_dict = self.create_dict_layout()
                # json_dict["info"]["contributor"] = "PMC Open Access Subset" if (re.search("pmc", self.src_file_path[i]))  else "arXiv"
                # json_dict["info"]["description"] = "Exported from PMC Open Access Subset" if (re.search("pmc", self.src_file_path[i]))  else "Exported from arXiv Open-access Archive"
                image_dict = self.set_image_properties(os.path.split(coco.coco_file_path[i])[1].replace(".json", ".jpg"), image_id)
                
                # Each Image present in the file is fetched and added to a cocoData object
                for doc_object in self.src_dictionary[i].values:
                    object_dict = self.set_object_properties(doc_object, doc_object_id, image_id)
                    # Add the object properties to the annotations key in COCO
                    json_dict["annotations"].append(object_dict)
                    # Increment the object ID for next annotated object in the file
                    doc_object_id += 1

                # Increment the Image ID for the next Image in the file
                image_id+=1
                # Extract Image width and height if annotations exist. There has to be atleast one annotation for an image to have the dimension attributes.
                # if len(content) > 0:
                #     image_dict["width"] = content[0]["page_width"]
                #     image_dict["height"] = content[0]["page_height"]
                # # Add the image properties to the Images key in COCO
                json_dict["images"].append(image_dict)
                self.coco_dictionary.append(json_dict)
        except:
            traceback.print_exc()

    # Converts final dictionary in COCO format for storing into file.
    def save_coco_dataset(self):
        try:
            for i in tqdm(range(len(self.coco_file_path))):
                coco_file_dir = os.path.split(self.coco_file_path[i])[0]
                if not os.path.exists(coco_file_dir):
                    # Creates the parent folder and all the subfolders for the file.
                    #   Does not throw an error if parent or any subfolders already exists.
                    Path(coco_file_dir).mkdir(parents=True, exist_ok=True)

                output_file = open(self.coco_file_path[i], mode="w")
                output_file.writelines(json.dumps(self.coco_dictionary[i], indent=4))
        except:
            traceback.print_exc()
        # finally:
        #     # output_file.close()

# %%
coco = COCOData()

# %%
coco.read_src_folder("/media/shivamsnaik/Windows-SSD/Users/shiva/DATASET/DocBank/DocBank_samples/", "/media/shivamsnaik/Windows-SSD/Users/shiva/DATASET/DocBank/DocBank-coco/")
# Out:
# Loading Source Files: 100it [00:00, 381.33it/s]

# %%
coco.convert_to_coco()
# Out:
# Convering Source JSON to COCO JSON: 100%|██████████| 100/100 [00:00<00:00, 414.01it/s]

# %%
coco.coco_dictionary[0]
# Out:
# {'info': {'year': '',
#   'version': '1',
#   'description': '',
#   'contributor': '',
#   'url': '',
#   'date_created': ''},
#  'licenses': [],
#  'categories': [{'id': 0, 'name': 'Abstract', 'supercategory': ''},
#   {'id': 1, 'name': 'Author', 'supercategory': ''},
#   {'id': 2, 'name': 'Caption', 'supercategory': ''},
#   {'id': 3, 'name': 'Equation', 'supercategory': ''},
#   {'id': 4, 'name': 'Figure', 'supercategory': ''},
#   {'id': 5, 'name': 'Footer', 'supercategory': ''},
#   {'id': 6, 'name': 'List', 'supercategory': ''},
#   {'id': 7, 'name': 'Paragraph', 'supercategory': ''},
#   {'id': 8, 'name': 'Reference', 'supercategory': ''},
#   {'id': 9, 'name': 'Section', 'supercategory': ''},
#   {'id': 10, 'name': 'Table', 'supercategory': ''},
#   {'id': 11, 'name': 'Title', 'supercategory': ''},
#   {'id': 12, 'name': 'Date', 'supercategory': ''}],
#  'images': [{'id': 0,
#    'license': '',
#    'file_name': '211.tar_1611.00049.gz_NNLLpaper_14.jpg',
#    'height': '',
#    'width': '',
#    'date_captured': ''}],
#  'annotations': [{'id': 0,
#    'image_id': 0,
#    'iscrowd': 0,
#    'segmentation': [],
#    'category_id': 7,
#    'bbox': [326, 99, 20, 11],
#    'area': 220},
#   {'id': 1,
#    'image_id': 0,
#    'iscrowd': 0,
#    'segmentation': [],
#    'category_id': 7,
#    'bbox': [359, 119, 22, 10],
#    'area': 220},
#   {'id': 2,
#    'image_id': 0,
#    'iscrowd': 0,
#    'segmentation': [],
#    'category_id': 7,
#    'bbox': [384, 119, 11, 10],
#    'area': 110},
#   {'id': 3,
#    'image_id': 0,
#    'iscrowd': 0,
#    'segmentation': [],
#    'category_id': 7,
#    'bbox': [398, 119, 19, 10],
#    'area': 190},
#   {'id': 4,
#    'image_id': 0,
#    'iscrowd': 0,
#    'segmentation': [],
#    'category_id': 7,
#    'bbox': [326, 137, 20, 11],
#    'area': 220},
#   {'id': 5,
#    'image_id': 0,
#    'iscrowd': 0,
#    'segmentation': [],
#    'category_id': 7,
#    'bbox': [326, 174, 20, 11],
#    'area': 220},
#   {'id': 6,
#    'image_id': 0,
#    'iscrowd': 0,
#    'segmentation': [],
#    'category_id': 7,
#    'bbox': [253, 181, 69, 4],
#    'area': 276},
#   {'id': 7,
#    'image_id': 0,
#    'iscrowd': 0,
#    'segmentation': [],
#    'category_id': 7,
#    'bbox': [302, 186, 20, 8],
#    'area': 160},
#   {'id': 8,
#    'image_id': 0,
#    'iscrowd': 0,
#    'segmentation': [],
#    'category_id': 7,
#    'bbox': [302, 194, 20, 8],
#    'area': 160},
#   {'id': 9,
#    'image_id': 0,
#    'iscrowd': 0,
#    'segmentation': [],
#    'category_id': 7,
#    'bbox': [253, 201, 69, 4],
#    'area': 276},
#   {'id': 10,
#    'image_id': 0,
#    'iscrowd': 0,
#    'segmentation': [],
#    'category_id': 7,
#    'bbox': [253, 210, 69, 9],
#    'area': 621},
#   {'id': 11,
#    'image_id': 0,
#    'iscrowd': 0,
#    'segmentation': [],
#    'category_id': 7,
#    'bbox': [326, 212, 20, 11],
#    'area': 220},
#   {'id': 12,
#    'image_id': 0,
#    'iscrowd': 0,
#    'segmentation': [],
#    'category_id': 7,
#    'bbox': [385, 239, 6, 33],
#    'area': 198},
#   {'id': 13,
#    'image_id': 0,
#    'iscrowd': 0,
#    'segmentation': [],
#    'category_id': 7,
#    'bbox': [402, 239, 6, 33],
#    'area': 198},
#   {'id': 14,
#    'image_id': 0,
#    'iscrowd': 0,
#    'segmentation': [],
#    'category_id': 7,
#    'bbox': [623, 238, 6, 34],
#    'area': 204},
#   {'id': 15,
#    'image_id': 0,
#    'iscrowd': 0,
#    'segmentation': [],
#    'category_id': 7,
#    'bbox': [640, 238, 6, 34],
#    'area': 204},
#   {'id': 16,
#    'image_id': 0,
#    'iscrowd': 0,
#    'segmentation': [],
#    'category_id': 7,
#    'bbox': [326, 249, 20, 11],
#    'area': 220},
#   {'id': 17,
#    'image_id': 0,
#    'iscrowd': 0,
#    'segmentation': [],
#    'category_id': 7,
#    'bbox': [410, 256, 10, 10],
#    'area': 100},
#   {'id': 18,
#    'image_id': 0,
#    'iscrowd': 0,
#    'segmentation': [],
#    'category_id': 7,
#    'bbox': [391, 266, 10, 7],
#    'area': 70},
#   {'id': 19,
#    'image_id': 0,
#    'iscrowd': 0,
#    'segmentation': [],
#    'category_id': 7,
#    'bbox': [413, 269, 5, 10],
#    'area': 50},
#   {'id': 20,
#    'image_id': 0,
#    'iscrowd': 0,
#    'segmentation': [],
#    'category_id': 7,
#    'bbox': [629, 266, 10, 6],
#    'area': 60},
#   {'id': 21,
#    'image_id': 0,
#    'iscrowd': 0,
#    'segmentation': [],
#    'category_id': 7,
#    'bbox': [646, 262, 11, 10],
#    'area': 110},
#   {'id': 22,
#    'image_id': 0,
#    'iscrowd': 0,
#    'segmentation': [],
#    'category_id': 7,
#    'bbox': [326, 287, 20, 11],
#    'area': 220},
#   {'id': 23,
#    'image_id': 0,
#    'iscrowd': 0,
#    'segmentation': [],
#    'category_id': 7,
#    'bbox': [351, 294, 27, 11],
#    'area': 297},
#   {'id': 24,
#    'image_id': 0,
#    'iscrowd': 0,
#    'segmentation': [],
#    'category_id': 7,
#    'bbox': [392, 294, 24, 11],
#    'area': 264},
#   {'id': 25,
#    'image_id': 0,
#    'iscrowd': 0,
#    'segmentation': [],
#    'category_id': 7,
#    'bbox': [426, 294, 34, 11],
#    'area': 374},
#   {'id': 26,
#    'image_id': 0,
#    'iscrowd': 0,
#    'segmentation': [],
#    'category_id': 7,
#    'bbox': [465, 294, 35, 11],
#    'area': 385},
#   {'id': 27,
#    'image_id': 0,
#    'iscrowd': 0,
#    'segmentation': [],
#    'category_id': 7,
#    'bbox': [548, 294, 26, 11],
#    'area': 286},
#   {'id': 28,
#    'image_id': 0,
#    'iscrowd': 0,
#    'segmentation': [],
#    'category_id': 7,
#    'bbox': [588, 294, 25, 11],
#    'area': 275},
#   {'id': 29,
#    'image_id': 0,
#    'iscrowd': 0,
#    'segmentation': [],
#    'category_id': 7,
#    'bbox': [623, 294, 34, 11],
#    'area': 374},
#   {'id': 30,
#    'image_id': 0,
#    'iscrowd': 0,
#    'segmentation': [],
#    'category_id': 7,
#    'bbox': [662, 294, 34, 11],
#    'area': 374},
#   {'id': 31,
#    'image_id': 0,
#    'iscrowd': 0,
#    'segmentation': [],
#    'category_id': 7,
#    'bbox': [140, 342, 58, 14],
#    'area': 812},
#   {'id': 32,
#    'image_id': 0,
#    'iscrowd': 0,
#    'segmentation': [],
#    'category_id': 7,
#    'bbox': [207, 342, 16, 14],
#    'area': 224},
#   {'id': 33,
#    'image_id': 0,
#    'iscrowd': 0,
#    'segmentation': [],
#    'category_id': 2,
#    'bbox': [239, 342, 93, 14],
#    'area': 1302},
#   {'id': 34,
#    'image_id': 0,
#    'iscrowd': 0,
#    'segmentation': [],
#    'category_id': 2,
#    'bbox': [340, 342, 63, 14],
#    'area': 882},
#   {'id': 35,
#    'image_id': 0,
#    'iscrowd': 0,
#    'segmentation': [],
#    'category_id': 2,
#    'bbox': [412, 342, 64, 14],
#    'area': 896},
#   {'id': 36,
#    'image_id': 0,
#    'iscrowd': 0,
#    'segmentation': [],
#    'category_id': 2,
#    'bbox': [485, 342, 96, 14],
#    'area': 1344},
#   {'id': 37,
#    'image_id': 0,
#    'iscrowd': 0,
#    'segmentation': [],
#    'category_id': 2,
#    'bbox': [590, 342, 120, 14],
#    'area': 1680},
#   {'id': 38,
#    'image_id': 0,
#    'iscrowd': 0,
#    'segmentation': [],
#    'category_id': 2,
#    'bbox': [719, 342, 15, 14],
#    'area': 210},
#   {'id': 39,
#    'image_id': 0,
#    'iscrowd': 0,
#    'segmentation': [],
#    'category_id': 2,
#    'bbox': [743, 342, 25, 14],
#    'area': 350},
#   {'id': 40,
#    'image_id': 0,
#    'iscrowd': 0,
#    'segmentation': [],
#    'category_id': 2,
#    'bbox': [776, 342, 37, 14],
#    'area': 518},
#   {'id': 41,
#    'image_id': 0,
#    'iscrowd': 0,
#    'segmentation': [],
#    'category_id': 2,
#    'bbox': [822, 342, 38, 14],
#    'area': 532},
#   {'id': 42,
#    'image_id': 0,
#    'iscrowd': 0,
#    'segmentation': [],
#    'category_id': 2,
#    'bbox': [140, 361, 53, 13],
#    'area': 689},
#   {'id': 43,
#    'image_id': 0,
#    'iscrowd': 0,
#    'segmentation': [],
#    'category_id': 2,
#    'bbox': [198, 361, 53, 13],
#    'area': 689},
#   {'id': 44,
#    'image_id': 0,
#    'iscrowd': 0,
#    'segmentation': [],
#    'category_id': 2,
#    'bbox': [256, 361, 26, 13],
#    'area': 338},
#   {'id': 45,
#    'image_id': 0,
#    'iscrowd': 0,
#    'segmentation': [],
#    'category_id': 2,
#    'bbox': [286, 361, 35, 13],
#    'area': 455},
#   {'id': 46,
#    'image_id': 0,
#    'iscrowd': 0,
#    'segmentation': [],
#    'category_id': 2,
#    'bbox': [326, 361, 24, 13],
#    'area': 312},
#   {'id': 47,
#    'image_id': 0,
#    'iscrowd': 0,
#    'segmentation': [],
#    'category_id': 2,
#    'bbox': [355, 361, 54, 13],
#    'area': 702},
#   {'id': 48,
#    'image_id': 0,
#    'iscrowd': 0,
#    'segmentation': [],
#    'category_id': 2,
#    'bbox': [413, 361, 98, 13],
#    'area': 1274},
#   {'id': 49,
#    'image_id': 0,
#    'iscrowd': 0,
#    'segmentation': [],
#    'category_id': 2,
#    'bbox': [516, 361, 36, 13],
#    'area': 468},
#   {'id': 50,
#    'image_id': 0,
#    'iscrowd': 0,
#    'segmentation': [],
#    'category_id': 2,
#    'bbox': [557, 361, 54, 13],
#    'area': 702},
#   {'id': 51,
#    'image_id': 0,
#    'iscrowd': 0,
#    'segmentation': [],
#    'category_id': 2,
#    'bbox': [616, 361, 10, 13],
#    'area': 130},
#   {'id': 52,
#    'image_id': 0,
#    'iscrowd': 0,
#    'segmentation': [],
#    'category_id': 2,
#    'bbox': [650, 361, 14, 13],
#    'area': 182},
#   {'id': 53,
#    'image_id': 0,
#    'iscrowd': 0,
#    'segmentation': [],
#    'category_id': 2,
#    'bbox': [669, 361, 36, 13],
#    'area': 468},
#   {'id': 54,
#    'image_id': 0,
#    'iscrowd': 0,
#    'segmentation': [],
#    'category_id': 2,
#    'bbox': [710, 361, 39, 13],
#    'area': 507},
#   {'id': 55,
#    'image_id': 0,
#    'iscrowd': 0,
#    'segmentation': [],
#    'category_id': 2,
#    'bbox': [754, 361, 28, 13],
#    'area': 364},
#   {'id': 56,
#    'image_id': 0,
#    'iscrowd': 0,
#    'segmentation': [],
#    'category_id': 2,
#    'bbox': [787, 361, 11, 13],
#    'area': 143},
#   {'id': 57,
#    'image_id': 0,
#    'iscrowd': 0,
#    'segmentation': [],
#    'category_id': 2,
#    'bbox': [821, 361, 14, 13],
#    'area': 182},
#   {'id': 58,
#    'image_id': 0,
#    'iscrowd': 0,
#    'segmentation': [],
#    'category_id': 2,
#    'bbox': [840, 361, 18, 13],
#    'area': 234},
#   {'id': 59,
#    'image_id': 0,
#    'iscrowd': 0,
#    'segmentation': [],
#    'category_id': 2,
#    'bbox': [626, 366, 19, 10],
#    'area': 190},
#   {'id': 60,
#    'image_id': 0,
#    'iscrowd': 0,
#    'segmentation': [],
#    'category_id': 2,
#    'bbox': [798, 366, 18, 10],
#    'area': 180},
#   {'id': 61,
#    'image_id': 0,
#    'iscrowd': 0,
#    'segmentation': [],
#    'category_id': 2,
#    'bbox': [140, 379, 56, 14],
#    'area': 784},
#   {'id': 62,
#    'image_id': 0,
#    'iscrowd': 0,
#    'segmentation': [],
#    'category_id': 2,
#    'bbox': [211, 379, 31, 14],
#    'area': 434},
#   {'id': 63,
#    'image_id': 0,
#    'iscrowd': 0,
#    'segmentation': [],
#    'category_id': 2,
#    'bbox': [251, 379, 44, 14],
#    'area': 616},
#   {'id': 64,
#    'image_id': 0,
#    'iscrowd': 0,
#    'segmentation': [],
#    'category_id': 2,
#    'bbox': [303, 379, 54, 14],
#    'area': 756},
#   {'id': 65,
#    'image_id': 0,
#    'iscrowd': 0,
#    'segmentation': [],
#    'category_id': 2,
#    'bbox': [366, 379, 28, 14],
#    'area': 392},
#   {'id': 66,
#    'image_id': 0,
#    'iscrowd': 0,
#    'segmentation': [],
#    'category_id': 2,
#    'bbox': [403, 379, 67, 14],
#    'area': 938},
#   {'id': 67,
#    'image_id': 0,
#    'iscrowd': 0,
#    'segmentation': [],
#    'category_id': 2,
#    'bbox': [478, 379, 19, 14],
#    'area': 266},
#   {'id': 68,
#    'image_id': 0,
#    'iscrowd': 0,
#    'segmentation': [],
#    'category_id': 2,
#    'bbox': [506, 379, 24, 14],
#    'area': 336},
#   {'id': 69,
#    'image_id': 0,
#    'iscrowd': 0,
#    'segmentation': [],
#    'category_id': 2,
#    'bbox': [539, 379, 78, 14],
#    'area': 1092},
#   {'id': 70,
#    'image_id': 0,
#    'iscrowd': 0,
#    'segmentation': [],
#    'category_id': 2,
#    'bbox': [625, 379, 31, 14],
#    'area': 434},
#   {'id': 71,
#    'image_id': 0,
#    'iscrowd': 0,
#    'segmentation': [],
#    'category_id': 2,
#    'bbox': [664, 379, 62, 14],
#    'area': 868},
#   {'id': 72,
#    'image_id': 0,
#    'iscrowd': 0,
#    'segmentation': [],
#    'category_id': 2,
#    'bbox': [734, 379, 88, 14],
#    'area': 1232},
#   {'id': 73,
#    'image_id': 0,
#    'iscrowd': 0,
#    'segmentation': [],
#    'category_id': 2,
#    'bbox': [831, 379, 28, 14],
#    'area': 392},
#   {'id': 74,
#    'image_id': 0,
#    'iscrowd': 0,
#    'segmentation': [],
#    'category_id': 2,
#    'bbox': [140, 398, 101, 14],
#    'area': 1414},
#   {'id': 75,
#    'image_id': 0,
#    'iscrowd': 0,
#    'segmentation': [],
#    'category_id': 2,
#    'bbox': [247, 398, 96, 14],
#    'area': 1344},
#   {'id': 76,
#    'image_id': 0,
#    'iscrowd': 0,
#    'segmentation': [],
#    'category_id': 7,
#    'bbox': [140, 439, 68, 15],
#    'area': 1020},
#   {'id': 77,
#    'image_id': 0,
#    'iscrowd': 0,
#    'segmentation': [],
#    'category_id': 7,
#    'bbox': [216, 439, 27, 15],
#    'area': 405},
#   {'id': 78,
#    'image_id': 0,
#    'iscrowd': 0,
#    'segmentation': [],
#    'category_id': 7,
#    'bbox': [251, 439, 72, 15],
#    'area': 1080},
#   {'id': 79,
#    'image_id': 0,
#    'iscrowd': 0,
#    'segmentation': [],
#    'category_id': 7,
#    'bbox': [331, 439, 15, 15],
#    'area': 225},
#   {'id': 80,
#    'image_id': 0,
#    'iscrowd': 0,
#    'segmentation': [],
#    'category_id': 7,
#    'bbox': [355, 439, 54, 15],
#    'area': 810},
#   {'id': 81,
#    'image_id': 0,
#    'iscrowd': 0,
#    'segmentation': [],
#    'category_id': 7,
#    'bbox': [418, 439, 38, 15],
#    'area': 570},
#   {'id': 82,
#    'image_id': 0,
#    'iscrowd': 0,
#    'segmentation': [],
#    'category_id': 7,
#    'bbox': [465, 439, 26, 15],
#    'area': 390},
#   {'id': 83,
#    'image_id': 0,
#    'iscrowd': 0,
#    'segmentation': [],
#    'category_id': 7,
#    'bbox': [500, 439, 29, 15],
#    'area': 435},
#   {'id': 84,
#    'image_id': 0,
#    'iscrowd': 0,
#    'segmentation': [],
#    'category_id': 7,
#    'bbox': [538, 439, 58, 15],
#    'area': 870},
#   {'id': 85,
#    'image_id': 0,
#    'iscrowd': 0,
#    'segmentation': [],
#    'category_id': 7,
#    'bbox': [604, 439, 33, 15],
#    'area': 495},
#   {'id': 86,
#    'image_id': 0,
#    'iscrowd': 0,
#    'segmentation': [],
#    'category_id': 7,
#    'bbox': [645, 439, 10, 15],
#    'area': 150},
#   {'id': 87,
#    'image_id': 0,
#    'iscrowd': 0,
#    'segmentation': [],
#    'category_id': 7,
#    'bbox': [663, 439, 52, 15],
#    'area': 780},
#   {'id': 88,
#    'image_id': 0,
#    'iscrowd': 0,
#    'segmentation': [],
#    'category_id': 7,
#    'bbox': [724, 439, 48, 15],
#    'area': 720},
#   {'id': 89,
#    'image_id': 0,
#    'iscrowd': 0,
#    'segmentation': [],
#    'category_id': 7,
#    'bbox': [780, 439, 79, 15],
#    'area': 1185},
#   {'id': 90,
#    'image_id': 0,
#    'iscrowd': 0,
#    'segmentation': [],
#    'category_id': 7,
#    'bbox': [140, 459, 30, 15],
#    'area': 450},
#   {'id': 91,
#    'image_id': 0,
#    'iscrowd': 0,
#    'segmentation': [],
#    'category_id': 7,
#    'bbox': [179, 459, 99, 15],
#    'area': 1485},
#   {'id': 92,
#    'image_id': 0,
#    'iscrowd': 0,
#    'segmentation': [],
#    'category_id': 7,
#    'bbox': [292, 459, 33, 15],
#    'area': 495},
#   {'id': 93,
#    'image_id': 0,
#    'iscrowd': 0,
#    'segmentation': [],
#    'category_id': 7,
#    'bbox': [334, 459, 108, 15],
#    'area': 1620},
#   {'id': 94,
#    'image_id': 0,
#    'iscrowd': 0,
#    'segmentation': [],
#    'category_id': 7,
#    'bbox': [451, 459, 54, 15],
#    'area': 810},
#   {'id': 95,
#    'image_id': 0,
#    'iscrowd': 0,
#    'segmentation': [],
#    'category_id': 7,
#    'bbox': [514, 459, 57, 15],
#    'area': 855},
#   {'id': 96,
#    'image_id': 0,
#    'iscrowd': 0,
#    'segmentation': [],
#    'category_id': 7,
#    'bbox': [579, 459, 17, 15],
#    'area': 255},
#   {'id': 97,
#    'image_id': 0,
#    'iscrowd': 0,
#    'segmentation': [],
#    'category_id': 7,
#    'bbox': [605, 459, 47, 15],
#    'area': 705},
#   {'id': 98,
#    'image_id': 0,
#    'iscrowd': 0,
#    'segmentation': [],
#    'category_id': 7,
#    'bbox': [661, 459, 39, 15],
#    'area': 585},
#   {'id': 99,
#    'image_id': 0,
#    'iscrowd': 0,
#    'segmentation': [],
#    'category_id': 7,
#    'bbox': [709, 459, 49, 15],
#    'area': 735},
#   {'id': 100,
#    'image_id': 0,
#    'iscrowd': 0,
#    'segmentation': [],
#    'category_id': 7,
#    'bbox': [767, 459, 27, 15],
#    'area': 405},
#   {'id': 101,
#    'image_id': 0,
#    'iscrowd': 0,
#    'segmentation': [],
#    'category_id': 7,
#    'bbox': [803, 459, 57, 15],
#    'area': 855},
#   {'id': 102,
#    'image_id': 0,
#    'iscrowd': 0,
#    'segmentation': [],
#    'category_id': 7,
#    'bbox': [140, 479, 100, 15],
#    'area': 1500},
#   {'id': 103,
#    'image_id': 0,
#    'iscrowd': 0,
#    'segmentation': [],
#    'category_id': 7,
#    'bbox': [246, 479, 66, 15],
#    'area': 990},
#   {'id': 104,
#    'image_id': 0,
#    'iscrowd': 0,
#    'segmentation': [],
#    'category_id': 7,
#    'bbox': [318, 479, 37, 15],
#    'area': 555},
#   {'id': 105,
#    'image_id': 0,
#    'iscrowd': 0,
#    'segmentation': [],
#    'category_id': 7,
#    'bbox': [361, 479, 10, 15],
#    'area': 150},
#   {'id': 106,
#    'image_id': 0,
#    'iscrowd': 0,
#    'segmentation': [],
#    'category_id': 7,
#    'bbox': [377, 479, 108, 15],
#    'area': 1620},
#   {'id': 107,
#    'image_id': 0,
#    'iscrowd': 0,
#    'segmentation': [],
#    'category_id': 9,
#    'bbox': [140, 499, 28, 15],
#    'area': 420},
#   {'id': 108,
#    'image_id': 0,
#    'iscrowd': 0,
#    'segmentation': [],
#    'category_id': 9,
#    'bbox': [190, 499, 107, 15],
#    'area': 1605},
#   {'id': 109,
#    'image_id': 0,
#    'iscrowd': 0,
#    'segmentation': [],
#    'category_id': 9,
#    'bbox': [305, 499, 121, 15],
#    'area': 1815},
#   {'id': 110,
#    'image_id': 0,
#    'iscrowd': 0,
#    'segmentation': [],
#    'category_id': 7,
#    'bbox': [174, 527, 17, 15],
#    'area': 255},
#   {'id': 111,
#    'image_id': 0,
#    'iscrowd': 0,
#    'segmentation': [],
#    'category_id': 7,
#    'bbox': [200, 527, 31, 15],
#    'area': 465},
#   {'id': 112,
#    'image_id': 0,
#    'iscrowd': 0,
#    'segmentation': [],
#    'category_id': 7,
#    'bbox': [239, 527, 57, 15],
#    'area': 855},
#   {'id': 113,
#    'image_id': 0,
#    'iscrowd': 0,
#    'segmentation': [],
#    'category_id': 7,
#    'bbox': [304, 527, 22, 15],
#    'area': 330},
#   {'id': 114,
#    'image_id': 0,
#    'iscrowd': 0,
#    'segmentation': [],
#    'category_id': 7,
#    'bbox': [334, 527, 58, 15],
#    'area': 870},
#   {'id': 115,
#    'image_id': 0,
#    'iscrowd': 0,
#    'segmentation': [],
#    'category_id': 7,
#    'bbox': [400, 527, 55, 15],
#    'area': 825},
#   {'id': 116,
#    'image_id': 0,
#    'iscrowd': 0,
#    'segmentation': [],
#    'category_id': 7,
#    'bbox': [463, 527, 23, 15],
#    'area': 345},
#   {'id': 117,
#    'image_id': 0,
#    'iscrowd': 0,
#    'segmentation': [],
#    'category_id': 7,
#    'bbox': [494, 527, 89, 15],
#    'area': 1335},
#   {'id': 118,
#    'image_id': 0,
#    'iscrowd': 0,
#    'segmentation': [],
#    'category_id': 7,
#    'bbox': [591, 527, 111, 15],
#    'area': 1665},
#   {'id': 119,
#    'image_id': 0,
#    'iscrowd': 0,
#    'segmentation': [],
#    'category_id': 7,
#    'bbox': [716, 527, 18, 15],
#    'area': 270},
#   {'id': 120,
#    'image_id': 0,
#    'iscrowd': 0,
#    'segmentation': [],
#    'category_id': 7,
#    'bbox': [742, 527, 87, 15],
#    'area': 1305},
#   {'id': 121,
#    'image_id': 0,
#    'iscrowd': 0,
#    'segmentation': [],
#    'category_id': 7,
#    'bbox': [838, 527, 21, 15],
#    'area': 315},
#   {'id': 122,
#    'image_id': 0,
#    'iscrowd': 0,
#    'segmentation': [],
#    'category_id': 7,
#    'bbox': [140, 547, 73, 15],
#    'area': 1095},
#   {'id': 123,
#    'image_id': 0,
#    'iscrowd': 0,
#    'segmentation': [],
#    'category_id': 6,
#    'bbox': [168, 556, 10, 26],
#    'area': 260},
#   {'id': 124,
#    'image_id': 0,
#    'iscrowd': 0,
#    'segmentation': [],
#    'category_id': 6,
#    'bbox': [187, 567, 27, 15],
#    'area': 405},
#   {'id': 125,
#    'image_id': 0,
#    'iscrowd': 0,
#    'segmentation': [],
#    'category_id': 6,
#    'bbox': [219, 567, 98, 15],
#    'area': 1470},
#   {'id': 126,
#    'image_id': 0,
#    'iscrowd': 0,
#    'segmentation': [],
#    'category_id': 6,
#    'bbox': [323, 567, 89, 15],
#    'area': 1335},
#   {'id': 127,
#    'image_id': 0,
#    'iscrowd': 0,
#    'segmentation': [],
#    'category_id': 6,
#    'bbox': [417, 567, 38, 15],
#    'area': 570},
#   {'id': 128,
#    'image_id': 0,
#    'iscrowd': 0,
#    'segmentation': [],
#    'category_id': 6,
#    'bbox': [460, 567, 59, 15],
#    'area': 885},
#   {'id': 129,
#    'image_id': 0,
#    'iscrowd': 0,
#    'segmentation': [],
#    'category_id': 6,
#    'bbox': [525, 567, 17, 15],
#    'area': 255},
#   {'id': 130,
#    'image_id': 0,
#    'iscrowd': 0,
#    'segmentation': [],
#    'category_id': 6,
#    'bbox': [547, 567, 27, 15],
#    'area': 405},
#   {'id': 131,
#    'image_id': 0,
#    'iscrowd': 0,
#    'segmentation': [],
#    'category_id': 6,
#    'bbox': [579, 567, 74, 15],
#    'area': 1110},
#   {'id': 132,
#    'image_id': 0,
#    'iscrowd': 0,
#    'segmentation': [],
#    'category_id': 6,
#    'bbox': [658, 567, 41, 15],
#    'area': 615},
#   {'id': 133,
#    'image_id': 0,
#    'iscrowd': 0,
#    'segmentation': [],
#    'category_id': 6,
#    'bbox': [704, 567, 16, 15],
#    'area': 240},
#   {'id': 134,
#    'image_id': 0,
#    'iscrowd': 0,
#    'segmentation': [],
#    'category_id': 6,
#    'bbox': [725, 567, 27, 15],
#    'area': 405},
#   {'id': 135,
#    'image_id': 0,
#    'iscrowd': 0,
#    'segmentation': [],
#    'category_id': 6,
#    'bbox': [757, 567, 28, 15],
#    'area': 420},
#   {'id': 136,
#    'image_id': 0,
#    'iscrowd': 0,
#    'segmentation': [],
#    'category_id': 6,
#    'bbox': [790, 567, 33, 15],
#    'area': 495},
#   {'id': 137,
#    'image_id': 0,
#    'iscrowd': 0,
#    'segmentation': [],
#    'category_id': 6,
#    'bbox': [829, 567, 30, 15],
#    'area': 450},
#   {'id': 138,
#    'image_id': 0,
#    'iscrowd': 0,
#    'segmentation': [],
#    'category_id': 6,
#    'bbox': [187, 587, 47, 15],
#    'area': 705},
#   {'id': 139,
#    'image_id': 0,
#    'iscrowd': 0,
#    'segmentation': [],
#    'category_id': 6,
#    'bbox': [240, 587, 48, 15],
#    'area': 720},
#   {'id': 140,
#    'image_id': 0,
#    'iscrowd': 0,
#    'segmentation': [],
#    'category_id': 6,
#    'bbox': [295, 587, 16, 15],
#    'area': 240},
#   {'id': 141,
#    'image_id': 0,
#    'iscrowd': 0,
#    'segmentation': [],
#    'category_id': 6,
#    'bbox': [317, 587, 27, 15],
#    'area': 405},
#   {'id': 142,
#    'image_id': 0,
#    'iscrowd': 0,
#    'segmentation': [],
#    'category_id': 6,
#    'bbox': [350, 587, 36, 15],
#    'area': 540},
#   {'id': 143,
#    'image_id': 0,
#    'iscrowd': 0,
#    'segmentation': [],
#    'category_id': 6,
#    'bbox': [393, 587, 45, 15],
#    'area': 675},
#   {'id': 144,
#    'image_id': 0,
#    'iscrowd': 0,
#    'segmentation': [],
#    'category_id': 6,
#    'bbox': [445, 587, 26, 15],
#    'area': 390},
#   {'id': 145,
#    'image_id': 0,
#    'iscrowd': 0,
#    'segmentation': [],
#    'category_id': 6,
#    'bbox': [168, 608, 10, 27],
#    'area': 270},
#   {'id': 146,
#    'image_id': 0,
#    'iscrowd': 0,
#    'segmentation': [],
#    'category_id': 6,
#    'bbox': [187, 619, 27, 16],
#    'area': 432},
#   {'id': 147,
#    'image_id': 0,
#    'iscrowd': 0,
#    'segmentation': [],
#    'category_id': 6,
#    'bbox': [221, 619, 98, 16],
#    'area': 1568},
#   {'id': 148,
#    'image_id': 0,
#    'iscrowd': 0,
#    'segmentation': [],
#    'category_id': 6,
#    'bbox': [326, 619, 90, 16],
#    'area': 1440},
#   {'id': 149,
#    'image_id': 0,
#    'iscrowd': 0,
#    'segmentation': [],
#    'category_id': 6,
#    'bbox': [423, 619, 37, 16],
#    'area': 592},
#   {'id': 150,
#    'image_id': 0,
#    'iscrowd': 0,
#    'segmentation': [],
#    'category_id': 6,
#    'bbox': [467, 619, 60, 16],
#    'area': 960},
#   {'id': 151,
#    'image_id': 0,
#    'iscrowd': 0,
#    'segmentation': [],
#    'category_id': 6,
#    'bbox': [534, 619, 17, 16],
#    'area': 272},
#   {'id': 152,
#    'image_id': 0,
#    'iscrowd': 0,
#    'segmentation': [],
#    'category_id': 6,
#    'bbox': [558, 619, 27, 16],
#    'area': 432},
#   {'id': 153,
#    'image_id': 0,
#    'iscrowd': 0,
#    'segmentation': [],
#    'category_id': 6,
#    'bbox': [592, 619, 74, 16],
#    'area': 1184},
#   {'id': 154,
#    'image_id': 0,
#    'iscrowd': 0,
#    'segmentation': [],
#    'category_id': 6,
#    'bbox': [673, 619, 41, 16],
#    'area': 656},
#   {'id': 155,
#    'image_id': 0,
#    'iscrowd': 0,
#    'segmentation': [],
#    'category_id': 6,
#    'bbox': [721, 619, 16, 16],
#    'area': 256},
#   {'id': 156,
#    'image_id': 0,
#    'iscrowd': 0,
#    'segmentation': [],
#    'category_id': 6,
#    'bbox': [744, 619, 26, 16],
#    'area': 416},
#   {'id': 157,
#    'image_id': 0,
#    'iscrowd': 0,
#    'segmentation': [],
#    'category_id': 6,
#    'bbox': [778, 619, 82, 16],
#    'area': 1312},
#   {'id': 158,
#    'image_id': 0,
#    'iscrowd': 0,
#    'segmentation': [],
#    'category_id': 6,
#    'bbox': [187, 640, 39, 15],
#    'area': 585},
#   {'id': 159,
#    'image_id': 0,
#    'iscrowd': 0,
#    'segmentation': [],
#    'category_id': 6,
#    'bbox': [232, 640, 18, 15],
#    'area': 270},
#   {'id': 160,
#    'image_id': 0,
#    'iscrowd': 0,
#    'segmentation': [],
#    'category_id': 6,
#    'bbox': [261, 640, 6, 15],
#    'area': 90},
#   {'id': 161,
#    'image_id': 0,
#    'iscrowd': 0,
#    'segmentation': [],
#    'category_id': 6,
#    'bbox': [250, 644, 13, 12],
#    'area': 156},
#   {'id': 162,
#    'image_id': 0,
#    'iscrowd': 0,
#    'segmentation': [],
#    'category_id': 6,
#    'bbox': [168, 661, 10, 26],
#    'area': 260},
#   {'id': 163,
#    'image_id': 0,
#    'iscrowd': 0,
#    'segmentation': [],
#    'category_id': 6,
#    'bbox': [187, 672, 27, 15],
#    'area': 405},
#   {'id': 164,
#    'image_id': 0,
#    'iscrowd': 0,
#    'segmentation': [],
#    'category_id': 6,
#    'bbox': [219, 672, 97, 15],
#    'area': 1455},
#   {'id': 165,
#    'image_id': 0,
#    'iscrowd': 0,
#    'segmentation': [],
#    'category_id': 6,
#    'bbox': [321, 672, 90, 15],
#    'area': 1350},
#   {'id': 166,
#    'image_id': 0,
#    'iscrowd': 0,
#    'segmentation': [],
#    'category_id': 6,
#    'bbox': [415, 672, 37, 15],
#    'area': 555},
#   {'id': 167,
#    'image_id': 0,
#    'iscrowd': 0,
#    'segmentation': [],
#    'category_id': 6,
#    'bbox': [457, 672, 59, 15],
#    'area': 885},
#   {'id': 168,
#    'image_id': 0,
#    'iscrowd': 0,
#    'segmentation': [],
#    'category_id': 6,
#    'bbox': [521, 672, 17, 15],
#    'area': 255},
#   {'id': 169,
#    'image_id': 0,
#    'iscrowd': 0,
#    'segmentation': [],
#    'category_id': 6,
#    'bbox': [543, 672, 26, 15],
#    'area': 390},
#   {'id': 170,
#    'image_id': 0,
#    'iscrowd': 0,
#    'segmentation': [],
#    'category_id': 6,
#    'bbox': [574, 672, 84, 15],
#    'area': 1260},
#   {'id': 171,
#    'image_id': 0,
#    'iscrowd': 0,
#    'segmentation': [],
#    'category_id': 6,
#    'bbox': [663, 672, 94, 15],
#    'area': 1410},
#   {'id': 172,
#    'image_id': 0,
#    'iscrowd': 0,
#    'segmentation': [],
#    'category_id': 6,
#    'bbox': [762, 672, 15, 15],
#    'area': 225},
#   {'id': 173,
#    'image_id': 0,
#    'iscrowd': 0,
#    'segmentation': [],
#    'category_id': 6,
#    'bbox': [782, 672, 26, 15],
#    'area': 390},
#   {'id': 174,
#    'image_id': 0,
#    'iscrowd': 0,
#    'segmentation': [],
#    'category_id': 6,
#    'bbox': [813, 672, 47, 15],
#    'area': 705},
#   {'id': 175,
#    'image_id': 0,
#    'iscrowd': 0,
#    'segmentation': [],
#    'category_id': 6,
#    'bbox': [187, 692, 54, 15],
#    'area': 810},
#   {'id': 176,
#    'image_id': 0,
#    'iscrowd': 0,
#    'segmentation': [],
#    'category_id': 6,
#    'bbox': [247, 691, 29, 16],
#    'area': 464},
#   {'id': 177,
#    'image_id': 0,
#    'iscrowd': 0,
#    'segmentation': [],
#    'category_id': 6,
#    'bbox': [257, 700, 8, 10],
#    'area': 80},
#   {'id': 178,
#    'image_id': 0,
#    'iscrowd': 0,
#    'segmentation': [],
#    'category_id': 6,
#    'bbox': [168, 714, 10, 26],
#    'area': 260},
#   {'id': 179,
#    'image_id': 0,
#    'iscrowd': 0,
#    'segmentation': [],
#    'category_id': 6,
#    'bbox': [187, 725, 27, 15],
#    'area': 405},
#   {'id': 180,
#    'image_id': 0,
#    'iscrowd': 0,
#    'segmentation': [],
#    'category_id': 6,
#    'bbox': [220, 725, 98, 15],
#    'area': 1470},
#   {'id': 181,
#    'image_id': 0,
#    'iscrowd': 0,
#    'segmentation': [],
#    'category_id': 6,
#    'bbox': [325, 725, 89, 15],
#    'area': 1335},
#   {'id': 182,
#    'image_id': 0,
#    'iscrowd': 0,
#    'segmentation': [],
#    'category_id': 6,
#    'bbox': [420, 725, 38, 15],
#    'area': 570},
#   {'id': 183,
#    'image_id': 0,
#    'iscrowd': 0,
#    'segmentation': [],
#    'category_id': 6,
#    'bbox': [464, 725, 59, 15],
#    'area': 885},
#   {'id': 184,
#    'image_id': 0,
#    'iscrowd': 0,
#    'segmentation': [],
#    'category_id': 6,
#    'bbox': [529, 725, 17, 15],
#    'area': 255},
#   {'id': 185,
#    'image_id': 0,
#    'iscrowd': 0,
#    'segmentation': [],
#    'category_id': 6,
#    'bbox': [553, 725, 26, 15],
#    'area': 390},
#   {'id': 186,
#    'image_id': 0,
#    'iscrowd': 0,
#    'segmentation': [],
#    'category_id': 6,
#    'bbox': [586, 725, 84, 15],
#    'area': 1260},
#   {'id': 187,
#    'image_id': 0,
#    'iscrowd': 0,
#    'segmentation': [],
#    'category_id': 6,
#    'bbox': [677, 725, 94, 15],
#    'area': 1410},
#   {'id': 188,
#    'image_id': 0,
#    'iscrowd': 0,
#    'segmentation': [],
#    'category_id': 6,
#    'bbox': [777, 725, 15, 15],
#    'area': 225},
#   {'id': 189,
#    'image_id': 0,
#    'iscrowd': 0,
#    'segmentation': [],
#    'category_id': 6,
#    'bbox': [799, 725, 26, 15],
#    'area': 390},
#   {'id': 190,
#    'image_id': 0,
#    'iscrowd': 0,
#    'segmentation': [],
#    'category_id': 6,
#    'bbox': [832, 725, 28, 15],
#    'area': 420},
#   {'id': 191,
#    'image_id': 0,
#    'iscrowd': 0,
#    'segmentation': [],
#    'category_id': 6,
#    'bbox': [187, 745, 53, 15],
#    'area': 795},
#   {'id': 192,
#    'image_id': 0,
#    'iscrowd': 0,
#    'segmentation': [],
#    'category_id': 6,
#    'bbox': [247, 744, 14, 16],
#    'area': 224},
#   {'id': 193,
#    'image_id': 0,
#    'iscrowd': 0,
#    'segmentation': [],
#    'category_id': 6,
#    'bbox': [267, 745, 6, 15],
#    'area': 90},
#   {'id': 194,
#    'image_id': 0,
#    'iscrowd': 0,
#    'segmentation': [],
#    'category_id': 6,
#    'bbox': [256, 753, 8, 10],
#    'area': 80},
#   {'id': 195,
#    'image_id': 0,
#    'iscrowd': 0,
#    'segmentation': [],
#    'category_id': 7,
#    'bbox': [174, 778, 26, 15],
#    'area': 390},
#   {'id': 196,
#    'image_id': 0,
#    'iscrowd': 0,
#    'segmentation': [],
#    'category_id': 7,
#    'bbox': [208, 778, 33, 15],
#    'area': 495},
#   {'id': 197,
#    'image_id': 0,
#    'iscrowd': 0,
#    'segmentation': [],
#    'category_id': 7,
#    'bbox': [249, 778, 23, 15],
#    'area': 345},
#   {'id': 198,
#    'image_id': 0,
#    'iscrowd': 0,
#    'segmentation': [],
#    'category_id': 7,
#    'bbox': [280, 778, 27, 15],
#    'area': 405},
#   {'id': 199,
#    'image_id': 0,
#    'iscrowd': 0,
#    'segmentation': [],
#    'category_id': 7,
#    'bbox': [314, 778, 58, 15],
#    'area': 870},
#   {'id': 200,
#    'image_id': 0,
#    'iscrowd': 0,
#    'segmentation': [],
#    'category_id': 7,
#    'bbox': [380, 778, 43, 15],
#    'area': 645},
#   {'id': 201,
#    'image_id': 0,
#    'iscrowd': 0,
#    'segmentation': [],
#    'category_id': 7,
#    'bbox': [430, 778, 16, 15],
#    'area': 240},
#   {'id': 202,
#    'image_id': 0,
#    'iscrowd': 0,
#    'segmentation': [],
#    'category_id': 7,
#    'bbox': [453, 778, 27, 15],
#    'area': 405},
#   {'id': 203,
#    'image_id': 0,
#    'iscrowd': 0,
#    'segmentation': [],
#    'category_id': 7,
#    'bbox': [488, 778, 104, 15],
#    'area': 1560},
#   {'id': 204,
#    'image_id': 0,
#    'iscrowd': 0,
#    'segmentation': [],
#    'category_id': 7,
#    'bbox': [600, 778, 39, 15],
#    'area': 585},
#   {'id': 205,
#    'image_id': 0,
#    'iscrowd': 0,
#    'segmentation': [],
#    'category_id': 7,
#    'bbox': [647, 778, 17, 15],
#    'area': 255},
#   {'id': 206,
#    'image_id': 0,
#    'iscrowd': 0,
#    'segmentation': [],
#    'category_id': 7,
#    'bbox': [672, 778, 11, 15],
#    'area': 165},
#   {'id': 207,
#    'image_id': 0,
#    'iscrowd': 0,
#    'segmentation': [],
#    'category_id': 7,
#    'bbox': [710, 778, 15, 15],
#    'area': 225},
#   {'id': 208,
#    'image_id': 0,
#    'iscrowd': 0,
#    'segmentation': [],
#    'category_id': 7,
#    'bbox': [732, 778, 44, 15],
#    'area': 660},
#   {'id': 209,
#    'image_id': 0,
#    'iscrowd': 0,
#    'segmentation': [],
#    'category_id': 7,
#    'bbox': [788, 778, 54, 15],
#    'area': 810},
#   {'id': 210,
#    'image_id': 0,
#    'iscrowd': 0,
#    'segmentation': [],
#    'category_id': 7,
#    'bbox': [850, 778, 9, 15],
#    'area': 135},
#   {'id': 211,
#    'image_id': 0,
#    'iscrowd': 0,
#    'segmentation': [],
#    'category_id': 7,
#    'bbox': [683, 784, 18, 10],
#    'area': 180},
#   {'id': 212,
#    'image_id': 0,
#    'iscrowd': 0,
#    'segmentation': [],
#    'category_id': 7,
#    'bbox': [140, 798, 48, 15],
#    'area': 720},
#   {'id': 213,
#    'image_id': 0,
#    'iscrowd': 0,
#    'segmentation': [],
#    'category_id': 7,
#    'bbox': [194, 798, 27, 15],
#    'area': 405},
#   {'id': 214,
#    'image_id': 0,
#    'iscrowd': 0,
#    'segmentation': [],
#    'category_id': 7,
#    'bbox': [227, 798, 95, 15],
#    'area': 1425},
#   {'id': 215,
#    'image_id': 0,
#    'iscrowd': 0,
#    'segmentation': [],
#    'category_id': 7,
#    'bbox': [328, 798, 68, 15],
#    'area': 1020},
#   {'id': 216,
#    'image_id': 0,
#    'iscrowd': 0,
#    'segmentation': [],
#    'category_id': 7,
#    'bbox': [402, 798, 75, 15],
#    'area': 1125},
#   {'id': 217,
#    'image_id': 0,
#    'iscrowd': 0,
#    'segmentation': [],
#    'category_id': 7,
#    'bbox': [483, 798, 41, 15],
#    'area': 615},
#   {'id': 218,
#    'image_id': 0,
#    'iscrowd': 0,
#    'segmentation': [],
#    'category_id': 7,
#    'bbox': [530, 798, 98, 15],
#    'area': 1470},
#   {'id': 219,
#    'image_id': 0,
#    'iscrowd': 0,
#    'segmentation': [],
#    'category_id': 7,
#    'bbox': [635, 798, 30, 15],
#    'area': 450},
#   {'id': 220,
#    'image_id': 0,
#    'iscrowd': 0,
#    'segmentation': [],
#    'category_id': 7,
#    'bbox': [672, 798, 104, 15],
#    'area': 1560},
#   {'id': 221,
#    'image_id': 0,
#    'iscrowd': 0,
#    'segmentation': [],
#    'category_id': 7,
#    'bbox': [782, 798, 41, 15],
#    'area': 615},
#   {'id': 222,
#    'image_id': 0,
#    'iscrowd': 0,
#    'segmentation': [],
#    'category_id': 7,
#    'bbox': [830, 798, 30, 15],
#    'area': 450},
#   {'id': 223,
#    'image_id': 0,
#    'iscrowd': 0,
#    'segmentation': [],
#    'category_id': 7,
#    'bbox': [140, 818, 74, 15],
#    'area': 1110},
#   {'id': 224,
#    'image_id': 0,
#    'iscrowd': 0,
#    'segmentation': [],
#    'category_id': 7,
#    'bbox': [220, 818, 23, 15],
#    'area': 345},
#   {'id': 225,
#    'image_id': 0,
#    'iscrowd': 0,
#    'segmentation': [],
#    'category_id': 7,
#    'bbox': [250, 818, 20, 15],
#    'area': 300},
#   {'id': 226,
#    'image_id': 0,
#    'iscrowd': 0,
#    'segmentation': [],
#    'category_id': 7,
#    'bbox': [276, 818, 16, 15],
#    'area': 240},
#   {'id': 227,
#    'image_id': 0,
#    'iscrowd': 0,
#    'segmentation': [],
#    'category_id': 7,
#    'bbox': [298, 818, 27, 15],
#    'area': 405},
#   {'id': 228,
#    'image_id': 0,
#    'iscrowd': 0,
#    'segmentation': [],
#    'category_id': 7,
#    'bbox': [331, 818, 106, 15],
#    'area': 1590},
#   {'id': 229,
#    'image_id': 0,
#    'iscrowd': 0,
#    'segmentation': [],
#    'category_id': 7,
#    'bbox': [443, 818, 45, 15],
#    'area': 675},
#   {'id': 230,
#    'image_id': 0,
#    'iscrowd': 0,
#    'segmentation': [],
#    'category_id': 7,
#    'bbox': [494, 818, 53, 15],
#    'area': 795},
#   {'id': 231,
#    'image_id': 0,
#    'iscrowd': 0,
#    'segmentation': [],
#    'category_id': 7,
#    'bbox': [556, 818, 27, 15],
#    'area': 405},
#   {'id': 232,
#    'image_id': 0,
#    'iscrowd': 0,
#    'segmentation': [],
#    'category_id': 7,
#    'bbox': [589, 818, 62, 15],
#    'area': 930},
#   {'id': 233,
#    'image_id': 0,
#    'iscrowd': 0,
#    'segmentation': [],
#    'category_id': 7,
#    'bbox': [657, 818, 35, 15],
#    'area': 525},
#   {'id': 234,
#    'image_id': 0,
#    'iscrowd': 0,
#    'segmentation': [],
#    'category_id': 7,
#    'bbox': [699, 818, 23, 15],
#    'area': 345},
#   {'id': 235,
#    'image_id': 0,
#    'iscrowd': 0,
#    'segmentation': [],
#    'category_id': 7,
#    'bbox': [728, 818, 20, 15],
#    'area': 300},
#   {'id': 236,
#    'image_id': 0,
#    'iscrowd': 0,
#    'segmentation': [],
#    'category_id': 7,
#    'bbox': [755, 818, 15, 15],
#    'area': 225},
#   {'id': 237,
#    'image_id': 0,
#    'iscrowd': 0,
#    'segmentation': [],
#    'category_id': 7,
#    'bbox': [776, 818, 27, 15],
#    'area': 405},
#   {'id': 238,
#    'image_id': 0,
#    'iscrowd': 0,
#    'segmentation': [],
#    'category_id': 7,
#    'bbox': [809, 818, 51, 15],
#    'area': 765},
#   {'id': 239,
#    'image_id': 0,
#    'iscrowd': 0,
#    'segmentation': [],
#    'category_id': 7,
#    'bbox': [140, 838, 61, 15],
#    'area': 915},
#   {'id': 240,
#    'image_id': 0,
#    'iscrowd': 0,
#    'segmentation': [],
#    'category_id': 7,
#    'bbox': [207, 838, 27, 15],
#    'area': 405},
#   {'id': 241,
#    'image_id': 0,
#    'iscrowd': 0,
#    'segmentation': [],
#    'category_id': 7,
#    'bbox': [240, 838, 104, 15],
#    'area': 1560},
#   {'id': 242,
#    'image_id': 0,
#    'iscrowd': 0,
#    'segmentation': [],
#    'category_id': 7,
#    'bbox': [350, 838, 41, 15],
#    'area': 615},
#   {'id': 243,
#    'image_id': 0,
#    'iscrowd': 0,
#    'segmentation': [],
#    'category_id': 7,
#    'bbox': [397, 838, 39, 15],
#    'area': 585},
#   {'id': 244,
#    'image_id': 0,
#    'iscrowd': 0,
#    'segmentation': [],
#    'category_id': 7,
#    'bbox': [442, 838, 96, 15],
#    'area': 1440},
#   {'id': 245,
#    'image_id': 0,
#    'iscrowd': 0,
#    'segmentation': [],
#    'category_id': 7,
#    'bbox': [544, 838, 41, 15],
#    'area': 615},
#   {'id': 246,
#    'image_id': 0,
#    'iscrowd': 0,
#    'segmentation': [],
#    'category_id': 7,
#    'bbox': [591, 838, 23, 15],
#    'area': 345},
#   {'id': 247,
#    'image_id': 0,
#    'iscrowd': 0,
#    'segmentation': [],
#    'category_id': 7,
#    'bbox': [620, 838, 43, 15],
#    'area': 645},
#   {'id': 248,
#    'image_id': 0,
#    'iscrowd': 0,
#    'segmentation': [],
#    'category_id': 7,
#    'bbox': [669, 838, 13, 15],
#    'area': 195},
#   {'id': 249,
#    'image_id': 0,
#    'iscrowd': 0,
#    'segmentation': [],
#    'category_id': 7,
#    'bbox': [688, 838, 70, 15],
#    'area': 1050},
#   {'id': 250,
#    'image_id': 0,
#    'iscrowd': 0,
#    'segmentation': [],
#    'category_id': 7,
#    'bbox': [764, 838, 16, 15],
#    'area': 240},
#   {'id': 251,
#    'image_id': 0,
#    'iscrowd': 0,
#    'segmentation': [],
#    'category_id': 7,
#    'bbox': [786, 838, 26, 15],
#    'area': 390},
#   {'id': 252,
#    'image_id': 0,
#    'iscrowd': 0,
#    'segmentation': [],
#    'category_id': 7,
#    'bbox': [818, 838, 41, 15],
#    'area': 615},
#   {'id': 253,
#    'image_id': 0,
#    'iscrowd': 0,
#    'segmentation': [],
#    'category_id': 7,
#    'bbox': [474, 915, 10, 15],
#    'area': 150},
#   {'id': 254,
#    'image_id': 0,
#    'iscrowd': 0,
#    'segmentation': [],
#    'category_id': 7,
#    'bbox': [490, 915, 19, 15],
#    'area': 285},
#   {'id': 255,
#    'image_id': 0,
#    'iscrowd': 0,
#    'segmentation': [],
#    'category_id': 7,
#    'bbox': [515, 915, 10, 15],
#    'area': 150},
#   {'id': 256,
#    'image_id': 0,
#    'iscrowd': 0,
#    'segmentation': [],
#    'category_id': 4,
#    'bbox': [303, 100, 393, 205],
#    'area': 80565},
#   {'id': 257,
#    'image_id': 0,
#    'iscrowd': 0,
#    'segmentation': [],
#    'category_id': 7,
#    'bbox': [364, 163, 0, 75],
#    'area': 0},
#   {'id': 258,
#    'image_id': 0,
#    'iscrowd': 0,
#    'segmentation': [],
#    'category_id': 7,
#    'bbox': [363, 163, 3, 0],
#    'area': 0},
#   {'id': 259,
#    'image_id': 0,
#    'iscrowd': 0,
#    'segmentation': [],
#    'category_id': 7,
#    'bbox': [363, 238, 3, 0],
#    'area': 0},
#   {'id': 260,
#    'image_id': 0,
#    'iscrowd': 0,
#    'segmentation': [],
#    'category_id': 7,
#    'bbox': [404, 152, 0, 55],
#    'area': 0},
#   {'id': 261,
#    'image_id': 0,
#    'iscrowd': 0,
#    'segmentation': [],
#    'category_id': 7,
#    'bbox': [403, 152, 2, 0],
#    'area': 0},
#   {'id': 262,
#    'image_id': 0,
#    'iscrowd': 0,
#    'segmentation': [],
#    'category_id': 7,
#    'bbox': [403, 207, 2, 0],
#    'area': 0},
#   {'id': 263,
#    'image_id': 0,
#    'iscrowd': 0,
#    'segmentation': [],
#    'category_id': 7,
#    'bbox': [443, 168, 0, 40],
#    'area': 0},
#   {'id': 264,
#    'image_id': 0,
#    'iscrowd': 0,
#    'segmentation': [],
#    'category_id': 7,
#    'bbox': [442, 168, 2, 0],
#    'area': 0},
#   {'id': 265,
#    'image_id': 0,
#    'iscrowd': 0,
#    'segmentation': [],
#    'category_id': 7,
#    'bbox': [442, 208, 2, 0],
#    'area': 0},
#   {'id': 266,
#    'image_id': 0,
#    'iscrowd': 0,
#    'segmentation': [],
#    'category_id': 7,
#    'bbox': [482, 168, 0, 21],
#    'area': 0},
#   {'id': 267,
#    'image_id': 0,
#    'iscrowd': 0,
#    'segmentation': [],
#    'category_id': 7,
#    'bbox': [481, 168, 3, 0],
#    'area': 0},
#   {'id': 268,
#    'image_id': 0,
#    'iscrowd': 0,
#    'segmentation': [],
#    'category_id': 7,
#    'bbox': [481, 189, 3, 0],
#    'area': 0},
#   {'id': 269,
#    'image_id': 0,
#    'iscrowd': 0,
#    'segmentation': [],
#    'category_id': 7,
#    'bbox': [561, 199, 0, 76],
#    'area': 0},
#   {'id': 270,
#    'image_id': 0,
#    'iscrowd': 0,
#    'segmentation': [],
#    'category_id': 7,
#    'bbox': [560, 199, 2, 0],
#    'area': 0},
#   {'id': 271,
#    'image_id': 0,
#    'iscrowd': 0,
#    'segmentation': [],
#    'category_id': 7,
#    'bbox': [560, 275, 2, 0],
#    'area': 0},
#   {'id': 272,
#    'image_id': 0,
#    'iscrowd': 0,
#    'segmentation': [],
#    'category_id': 7,
#    'bbox': [600, 188, 0, 37],
#    'area': 0},
#   {'id': 273,
#    'image_id': 0,
#    'iscrowd': 0,
#    'segmentation': [],
#    'category_id': 7,
#    'bbox': [599, 188, 3, 0],
#    'area': 0},
#   {'id': 274,
#    'image_id': 0,
#    'iscrowd': 0,
#    'segmentation': [],
#    'category_id': 7,
#    'bbox': [599, 225, 3, 0],
#    'area': 0},
#   {'id': 275,
#    'image_id': 0,
#    'iscrowd': 0,
#    'segmentation': [],
#    'category_id': 7,
#    'bbox': [640, 137, 0, 62],
#    'area': 0},
#   {'id': 276,
#    'image_id': 0,
#    'iscrowd': 0,
#    'segmentation': [],
#    'category_id': 7,
#    'bbox': [639, 137, 2, 0],
#    'area': 0},
#   {'id': 277,
#    'image_id': 0,
#    'iscrowd': 0,
#    'segmentation': [],
#    'category_id': 7,
#    'bbox': [639, 199, 2, 0],
#    'area': 0},
#   {'id': 278,
#    'image_id': 0,
#    'iscrowd': 0,
#    'segmentation': [],
#    'category_id': 7,
#    'bbox': [679, 182, 0, 13],
#    'area': 0},
#   {'id': 279,
#    'image_id': 0,
#    'iscrowd': 0,
#    'segmentation': [],
#    'category_id': 7,
#    'bbox': [678, 182, 2, 0],
#    'area': 0},
#   {'id': 280,
#    'image_id': 0,
#    'iscrowd': 0,
#    'segmentation': [],
#    'category_id': 7,
#    'bbox': [678, 195, 2, 0],
#    'area': 0},
#   {'id': 281,
#    'image_id': 0,
#    'iscrowd': 0,
#    'segmentation': [],
#    'category_id': 7,
#    'bbox': [349, 292, 346, 0],
#    'area': 0},
#   {'id': 282,
#    'image_id': 0,
#    'iscrowd': 0,
#    'segmentation': [],
#    'category_id': 7,
#    'bbox': [349, 105, 0, 187],
#    'area': 0},
#   {'id': 283,
#    'image_id': 0,
#    'iscrowd': 0,
#    'segmentation': [],
#    'category_id': 7,
#    'bbox': [349, 105, 346, 0],
#    'area': 0},
#   {'id': 284,
#    'image_id': 0,
#    'iscrowd': 0,
#    'segmentation': [],
#    'category_id': 7,
#    'bbox': [695, 105, 0, 187],
#    'area': 0},
#   {'id': 285,
#    'image_id': 0,
#    'iscrowd': 0,
#    'segmentation': [],
#    'category_id': 7,
#    'bbox': [364, 290, 0, 2],
#    'area': 0},
#   {'id': 286,
#    'image_id': 0,
#    'iscrowd': 0,
#    'segmentation': [],
#    'category_id': 7,
#    'bbox': [404, 290, 0, 2],
#    'area': 0},
#   {'id': 287,
#    'image_id': 0,
#    'iscrowd': 0,
#    'segmentation': [],
#    'category_id': 7,
#    'bbox': [443, 290, 0, 2],
#    'area': 0},
#   {'id': 288,
#    'image_id': 0,
#    'iscrowd': 0,
#    'segmentation': [],
#    'category_id': 7,
#    'bbox': [482, 290, 0, 2],
#    'area': 0},
#   {'id': 289,
#    'image_id': 0,
#    'iscrowd': 0,
#    'segmentation': [],
#    'category_id': 7,
#    'bbox': [561, 290, 0, 2],
#    'area': 0},
#   {'id': 290,
#    'image_id': 0,
#    'iscrowd': 0,
#    'segmentation': [],
#    'category_id': 7,
#    'bbox': [600, 290, 0, 2],
#    'area': 0},
#   {'id': 291,
#    'image_id': 0,
#    'iscrowd': 0,
#    'segmentation': [],
#    'category_id': 7,
#    'bbox': [640, 290, 0, 2],
#    'area': 0},
#   {'id': 292,
#    'image_id': 0,
#    'iscrowd': 0,
#    'segmentation': [],
#    'category_id': 7,
#    'bbox': [679, 290, 0, 2],
#    'area': 0},
#   {'id': 293,
#    'image_id': 0,
#    'iscrowd': 0,
#    'segmentation': [],
#    'category_id': 7,
#    'bbox': [349, 292, 3, 0],
#    'area': 0},
#   {'id': 294,
#    'image_id': 0,
#    'iscrowd': 0,
#    'segmentation': [],
#    'category_id': 7,
#    'bbox': [349, 285, 2, 0],
#    'area': 0},
#   {'id': 295,
#    'image_id': 0,
#    'iscrowd': 0,
#    'segmentation': [],
#    'category_id': 7,
#    'bbox': [349, 277, 2, 0],
#    'area': 0},
#   {'id': 296,
#    'image_id': 0,
#    'iscrowd': 0,
#    'segmentation': [],
#    'category_id': 7,
#    'bbox': [349, 270, 2, 0],
#    'area': 0},
#   {'id': 297,
#    'image_id': 0,
#    'iscrowd': 0,
#    'segmentation': [],
#    'category_id': 7,
#    'bbox': [349, 262, 2, 0],
#    'area': 0},
#   {'id': 298,
#    'image_id': 0,
#    'iscrowd': 0,
#    'segmentation': [],
#    'category_id': 7,
#    'bbox': [349, 255, 3, 0],
#    'area': 0},
#   {'id': 299,
#    'image_id': 0,
#    'iscrowd': 0,
#    'segmentation': [],
#    'category_id': 7,
#    'bbox': [349, 247, 2, 0],
#    'area': 0},
#   {'id': 300,
#    'image_id': 0,
#    'iscrowd': 0,
#    'segmentation': [],
#    'category_id': 7,
#    'bbox': [349, 240, 2, 0],
#    'area': 0},
#   {'id': 301,
#    'image_id': 0,
#    'iscrowd': 0,
#    'segmentation': [],
#    'category_id': 7,
#    'bbox': [349, 232, 2, 0],
#    'area': 0},
#   {'id': 302,
#    'image_id': 0,
#    'iscrowd': 0,
#    'segmentation': [],
#    'category_id': 7,
#    'bbox': [349, 225, 2, 0],
#    'area': 0},
#   {'id': 303,
#    'image_id': 0,
#    'iscrowd': 0,
#    'segmentation': [],
#    'category_id': 7,
#    'bbox': [349, 217, 3, 0],
#    'area': 0},
#   {'id': 304,
#    'image_id': 0,
#    'iscrowd': 0,
#    'segmentation': [],
#    'category_id': 7,
#    'bbox': [349, 210, 2, 0],
#    'area': 0},
#   {'id': 305,
#    'image_id': 0,
#    'iscrowd': 0,
#    'segmentation': [],
#    'category_id': 7,
#    'bbox': [349, 202, 2, 0],
#    'area': 0},
#   {'id': 306,
#    'image_id': 0,
#    'iscrowd': 0,
#    'segmentation': [],
#    'category_id': 7,
#    'bbox': [349, 195, 2, 0],
#    'area': 0},
#   {'id': 307,
#    'image_id': 0,
#    'iscrowd': 0,
#    'segmentation': [],
#    'category_id': 7,
#    'bbox': [349, 187, 2, 0],
#    'area': 0},
#   {'id': 308,
#    'image_id': 0,
#    'iscrowd': 0,
#    'segmentation': [],
#    'category_id': 7,
#    'bbox': [349, 180, 3, 0],
#    'area': 0},
#   {'id': 309,
#    'image_id': 0,
#    'iscrowd': 0,
#    'segmentation': [],
#    'category_id': 7,
#    'bbox': [349, 172, 2, 0],
#    'area': 0},
#   {'id': 310,
#    'image_id': 0,
#    'iscrowd': 0,
#    'segmentation': [],
#    'category_id': 7,
#    'bbox': [349, 165, 2, 0],
#    'area': 0},
#   {'id': 311,
#    'image_id': 0,
#    'iscrowd': 0,
#    'segmentation': [],
#    'category_id': 7,
#    'bbox': [349, 157, 2, 0],
#    'area': 0},
#   {'id': 312,
#    'image_id': 0,
#    'iscrowd': 0,
#    'segmentation': [],
#    'category_id': 7,
#    'bbox': [349, 150, 2, 0],
#    'area': 0},
#   {'id': 313,
#    'image_id': 0,
#    'iscrowd': 0,
#    'segmentation': [],
#    'category_id': 7,
#    'bbox': [349, 142, 3, 0],
#    'area': 0},
#   {'id': 314,
#    'image_id': 0,
#    'iscrowd': 0,
#    'segmentation': [],
#    'category_id': 7,
#    'bbox': [349, 135, 2, 0],
#    'area': 0},
#   {'id': 315,
#    'image_id': 0,
#    'iscrowd': 0,
#    'segmentation': [],
#    'category_id': 7,
#    'bbox': [349, 127, 2, 0],
#    'area': 0},
#   {'id': 316,
#    'image_id': 0,
#    'iscrowd': 0,
#    'segmentation': [],
#    'category_id': 7,
#    'bbox': [349, 120, 2, 0],
#    'area': 0},
#   {'id': 317,
#    'image_id': 0,
#    'iscrowd': 0,
#    'segmentation': [],
#    'category_id': 7,
#    'bbox': [349, 112, 2, 0],
#    'area': 0},
#   {'id': 318,
#    'image_id': 0,
#    'iscrowd': 0,
#    'segmentation': [],
#    'category_id': 7,
#    'bbox': [349, 105, 3, 0],
#    'area': 0},
#   {'id': 319,
#    'image_id': 0,
#    'iscrowd': 0,
#    'segmentation': [],
#    'category_id': 7,
#    'bbox': [349, 105, 0, 1],
#    'area': 0},
#   {'id': 320,
#    'image_id': 0,
#    'iscrowd': 0,
#    'segmentation': [],
#    'category_id': 7,
#    'bbox': [364, 105, 0, 2],
#    'area': 0},
#   {'id': 321,
#    'image_id': 0,
#    'iscrowd': 0,
#    'segmentation': [],
#    'category_id': 7,
#    'bbox': [380, 105, 0, 1],
#    'area': 0},
#   {'id': 322,
#    'image_id': 0,
#    'iscrowd': 0,
#    'segmentation': [],
#    'category_id': 7,
#    'bbox': [396, 105, 0, 1],
#    'area': 0},
#   {'id': 323,
#    'image_id': 0,
#    'iscrowd': 0,
#    'segmentation': [],
#    'category_id': 7,
#    'bbox': [412, 105, 0, 1],
#    'area': 0},
#   {'id': 324,
#    'image_id': 0,
#    'iscrowd': 0,
#    'segmentation': [],
#    'category_id': 7,
#    'bbox': [427, 105, 0, 1],
#    'area': 0},
#   {'id': 325,
#    'image_id': 0,
#    'iscrowd': 0,
#    'segmentation': [],
#    'category_id': 7,
#    'bbox': [443, 105, 0, 2],
#    'area': 0},
#   {'id': 326,
#    'image_id': 0,
#    'iscrowd': 0,
#    'segmentation': [],
#    'category_id': 7,
#    'bbox': [459, 105, 0, 1],
#    'area': 0},
#   {'id': 327,
#    'image_id': 0,
#    'iscrowd': 0,
#    'segmentation': [],
#    'category_id': 7,
#    'bbox': [475, 105, 0, 1],
#    'area': 0},
#   {'id': 328,
#    'image_id': 0,
#    'iscrowd': 0,
#    'segmentation': [],
#    'category_id': 7,
#    'bbox': [490, 105, 0, 1],
#    'area': 0},
#   {'id': 329,
#    'image_id': 0,
#    'iscrowd': 0,
#    'segmentation': [],
#    'category_id': 7,
#    'bbox': [506, 105, 0, 1],
#    'area': 0},
#   {'id': 330,
#    'image_id': 0,
#    'iscrowd': 0,
#    'segmentation': [],
#    'category_id': 7,
#    'bbox': [522, 105, 0, 2],
#    'area': 0},
#   {'id': 331,
#    'image_id': 0,
#    'iscrowd': 0,
#    'segmentation': [],
#    'category_id': 7,
#    'bbox': [538, 105, 0, 1],
#    'area': 0},
#   {'id': 332,
#    'image_id': 0,
#    'iscrowd': 0,
#    'segmentation': [],
#    'category_id': 7,
#    'bbox': [553, 105, 0, 1],
#    'area': 0},
#   {'id': 333,
#    'image_id': 0,
#    'iscrowd': 0,
#    'segmentation': [],
#    'category_id': 7,
#    'bbox': [569, 105, 0, 1],
#    'area': 0},
#   {'id': 334,
#    'image_id': 0,
#    'iscrowd': 0,
#    'segmentation': [],
#    'category_id': 7,
#    'bbox': [585, 105, 0, 1],
#    'area': 0},
#   {'id': 335,
#    'image_id': 0,
#    'iscrowd': 0,
#    'segmentation': [],
#    'category_id': 7,
#    'bbox': [600, 105, 0, 2],
#    'area': 0},
#   {'id': 336,
#    'image_id': 0,
#    'iscrowd': 0,
#    'segmentation': [],
#    'category_id': 7,
#    'bbox': [616, 105, 0, 1],
#    'area': 0},
#   {'id': 337,
#    'image_id': 0,
#    'iscrowd': 0,
#    'segmentation': [],
#    'category_id': 7,
#    'bbox': [632, 105, 0, 1],
#    'area': 0},
#   {'id': 338,
#    'image_id': 0,
#    'iscrowd': 0,
#    'segmentation': [],
#    'category_id': 7,
#    'bbox': [648, 105, 0, 1],
#    'area': 0},
#   {'id': 339,
#    'image_id': 0,
#    'iscrowd': 0,
#    'segmentation': [],
#    'category_id': 7,
#    'bbox': [663, 105, 0, 1],
#    'area': 0},
#   {'id': 340,
#    'image_id': 0,
#    'iscrowd': 0,
#    'segmentation': [],
#    'category_id': 7,
#    'bbox': [679, 105, 0, 2],
#    'area': 0},
#   {'id': 341,
#    'image_id': 0,
#    'iscrowd': 0,
#    'segmentation': [],
#    'category_id': 7,
#    'bbox': [695, 105, 0, 1],
#    'area': 0},
#   {'id': 342,
#    'image_id': 0,
#    'iscrowd': 0,
#    'segmentation': [],
#    'category_id': 7,
#    'bbox': [692, 292, 3, 0],
#    'area': 0},
#   {'id': 343,
#    'image_id': 0,
#    'iscrowd': 0,
#    'segmentation': [],
#    'category_id': 7,
#    'bbox': [693, 285, 2, 0],
#    'area': 0},
#   {'id': 344,
#    'image_id': 0,
#    'iscrowd': 0,
#    'segmentation': [],
#    'category_id': 7,
#    'bbox': [693, 277, 2, 0],
#    'area': 0},
#   {'id': 345,
#    'image_id': 0,
#    'iscrowd': 0,
#    'segmentation': [],
#    'category_id': 7,
#    'bbox': [693, 270, 2, 0],
#    'area': 0},
#   {'id': 346,
#    'image_id': 0,
#    'iscrowd': 0,
#    'segmentation': [],
#    'category_id': 7,
#    'bbox': [693, 262, 2, 0],
#    'area': 0},
#   {'id': 347,
#    'image_id': 0,
#    'iscrowd': 0,
#    'segmentation': [],
#    'category_id': 7,
#    'bbox': [692, 255, 3, 0],
#    'area': 0},
#   {'id': 348,
#    'image_id': 0,
#    'iscrowd': 0,
#    'segmentation': [],
#    'category_id': 7,
#    'bbox': [693, 247, 2, 0],
#    'area': 0},
#   {'id': 349,
#    'image_id': 0,
#    'iscrowd': 0,
#    'segmentation': [],
#    'category_id': 7,
#    'bbox': [693, 240, 2, 0],
#    'area': 0},
#   {'id': 350,
#    'image_id': 0,
#    'iscrowd': 0,
#    'segmentation': [],
#    'category_id': 7,
#    'bbox': [693, 232, 2, 0],
#    'area': 0},
#   {'id': 351,
#    'image_id': 0,
#    'iscrowd': 0,
#    'segmentation': [],
#    'category_id': 7,
#    'bbox': [693, 225, 2, 0],
#    'area': 0},
#   {'id': 352,
#    'image_id': 0,
#    'iscrowd': 0,
#    'segmentation': [],
#    'category_id': 7,
#    'bbox': [692, 217, 3, 0],
#    'area': 0},
#   {'id': 353,
#    'image_id': 0,
#    'iscrowd': 0,
#    'segmentation': [],
#    'category_id': 7,
#    'bbox': [693, 210, 2, 0],
#    'area': 0},
#   {'id': 354,
#    'image_id': 0,
#    'iscrowd': 0,
#    'segmentation': [],
#    'category_id': 7,
#    'bbox': [693, 202, 2, 0],
#    'area': 0},
#   {'id': 355,
#    'image_id': 0,
#    'iscrowd': 0,
#    'segmentation': [],
#    'category_id': 7,
#    'bbox': [693, 195, 2, 0],
#    'area': 0},
#   {'id': 356,
#    'image_id': 0,
#    'iscrowd': 0,
#    'segmentation': [],
#    'category_id': 7,
#    'bbox': [693, 187, 2, 0],
#    'area': 0},
#   {'id': 357,
#    'image_id': 0,
#    'iscrowd': 0,
#    'segmentation': [],
#    'category_id': 7,
#    'bbox': [692, 180, 3, 0],
#    'area': 0},
#   {'id': 358,
#    'image_id': 0,
#    'iscrowd': 0,
#    'segmentation': [],
#    'category_id': 7,
#    'bbox': [693, 172, 2, 0],
#    'area': 0},
#   {'id': 359,
#    'image_id': 0,
#    'iscrowd': 0,
#    'segmentation': [],
#    'category_id': 7,
#    'bbox': [693, 165, 2, 0],
#    'area': 0},
#   {'id': 360,
#    'image_id': 0,
#    'iscrowd': 0,
#    'segmentation': [],
#    'category_id': 7,
#    'bbox': [693, 157, 2, 0],
#    'area': 0},
#   {'id': 361,
#    'image_id': 0,
#    'iscrowd': 0,
#    'segmentation': [],
#    'category_id': 7,
#    'bbox': [693, 150, 2, 0],
#    'area': 0},
#   {'id': 362,
#    'image_id': 0,
#    'iscrowd': 0,
#    'segmentation': [],
#    'category_id': 7,
#    'bbox': [692, 142, 3, 0],
#    'area': 0},
#   {'id': 363,
#    'image_id': 0,
#    'iscrowd': 0,
#    'segmentation': [],
#    'category_id': 7,
#    'bbox': [693, 135, 2, 0],
#    'area': 0},
#   {'id': 364,
#    'image_id': 0,
#    'iscrowd': 0,
#    'segmentation': [],
#    'category_id': 7,
#    'bbox': [693, 127, 2, 0],
#    'area': 0},
#   {'id': 365,
#    'image_id': 0,
#    'iscrowd': 0,
#    'segmentation': [],
#    'category_id': 7,
#    'bbox': [693, 120, 2, 0],
#    'area': 0},
#   {'id': 366,
#    'image_id': 0,
#    'iscrowd': 0,
#    'segmentation': [],
#    'category_id': 7,
#    'bbox': [693, 112, 2, 0],
#    'area': 0},
#   {'id': 367,
#    'image_id': 0,
#    'iscrowd': 0,
#    'segmentation': [],
#    'category_id': 7,
#    'bbox': [692, 105, 3, 0],
#    'area': 0}]}

# %%
coco.save_coco_dataset()
